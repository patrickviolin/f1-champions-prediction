# %% [markdown]
# #### 1. Adding the target variable

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/02_interim/04_info_after_feature_engineering.csv')

# %%
df['target'] = np.where(df['status_group'] == 'Finished', 1, 0)

# %% [markdown]
# #### 2. Dropping info that won't be used in training

# %%
df = df.drop(['resultId', 'raceId', 'driverId', 'date', 'statusId', 'status', 'status_group', 'positionOrder', 'laps',
              'qualifyId', 'q1', 'q2', 'q3', 'dob', 'round'
              ], axis=1)

# %% [markdown]
# #### 3. Separate X from y

# %%
X = df.drop('target', axis=1)
y = df[['year', 'target']]

# %% [markdown]
# #### 4. Time-series Split - Separate train from test

# %%
X_train = X[X['year'] <= 2020]
X_test = X[X['year'] > 2020]

y_train = y[y['year'] <= 2020]
y_test = y[y['year'] > 2020]

X_train = X_train.drop('year', axis=1)
X_test = X_test.drop('year', axis=1)

y_train = y_train.drop('year', axis=1)
y_test = y_test.drop('year', axis=1)

# %% [markdown]
# #### 5. Export data

# %%
datasets = [X_train, X_test, y_train, y_test]
datasets_names = ['X_train', 'X_test', 'y_train', 'y_test']

for i in range(len(datasets)):
    datasets[i].to_csv(f'../data/03_processed/{datasets_names[i]}.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[54], line 5
#       1 datasets = [X_train, X_test, y_train, y_test]
#       2 datasets_names = ['X_train', 'X_test', 'y_train', 'y_test']
#       3
#       4 for i in range(len(datasets)):
# ----> 5     datasets[i].to_parquet(f'../data/03_processed/{datasets_names[i]}.parquet', index=False)
#
# File D:\Users\Patrick\PycharmProjects\F1ChampionsPrediction\.venv\Lib\site-packages\pandas\core\frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3131         >>> content = f.read()
#    3132         """
#    3133         from pandas.io.parquet import to_parquet
#    3134
# -> 3135         return to_parquet(
#    3136             self,
#    3137             path,
#    3138             engine,
#
# File D:\Users\Patrick\PycharmProjects\F1ChampionsPrediction\.venv\Lib\site-packages\pandas\io\parquet.py:486, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     484 if isinstance(partition_cols, str):
#     485     partition_cols = [partition_cols]
# --> 486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     490 impl.write(
#     491     df,
#     492     path_or_buf,
#    (...)    498     **kwargs,
#     499 )
#
# File D:\Users\Patrick\PycharmProjects\F1ChampionsPrediction\.venv\Lib\site-packages\pandas\io\parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.
#  - `Import fastparquet` failed. fastparquet is required for parquet support. Use pip or conda to install the fastparquet package.
